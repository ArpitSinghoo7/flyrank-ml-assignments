# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %% [markdown]
# Unit of Analysis: A single row in this dataset represents one specific piece of content (a unique URL or content ID) along with its associated search and engagement metrics.
#
# Time Window: The dataset represents a historical snapshot of aggregated performance data, capturing metrics over a predefined 30-day trailing window.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %% [markdown]
# Features (Inputs): Metrics like word_count, char_count, search_volume, and competition.
#
# Label (Prediction): Metrics indicating visibility, such as impression_tier.
#
# Context (Tracking only): content_id and client_id.
#
# Excluded: Any PII or raw text identifiers (handled by the anonymization pipeline).

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
import pandas as pd
import duckdb

# 1. Load the dataset
df = pd.read_csv('../../data/raw/content_refresh_anonymized.csv')

# 2. Verify grain and count rows (using DuckDB as requested in the assignment)
print("--- Total Rows (Grain Check) ---")
print(duckdb.query("SELECT COUNT(*) AS total_rows FROM df").to_df())

# 3. Measure missing values for our features
print("\n--- Missing Values Check ---")
print(df.isnull().sum())
# Out:
# --- Total Rows (Grain Check) ---
#    total_rows
# 0       30000
#
# --- Missing Values Check ---
# content_id                    0
# client_id                     0
# search_volume              2468
# competition                2468
# competition_level          2610
# cpc                        2468
# content_type                  0
# main_intent                2374
# word_count                 7699
# char_count                 7699
# provider_used             21438
# model_used                 5733
# impressions_90d               0
# clicks_90d                    0
# pageviews_90d                 0
# sessions_90d                  0
# users_90d                     0
# engaged_sessions_90d          0
# ai_sessions_90d               0
# scroll_events_90d             0
# days_with_impressions         0
# days_with_sessions            0
# impressions_last_30d          0
# clicks_last_30d               0
# sessions_last_30d             0
# impressions_prev_30d          0
# ...

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %% [markdown]
# Data Limits:
#
# Unbalanced history: The dataset might skew heavily toward certain dominant topics or time periods, meaning our model could overfit to those specific patterns.
#
# GSC-only early rows: Older records might rely strictly on Google Search Console data, missing broader engagement context (like bounce rate) that was added later.
#
# Window overlaps: Because metrics are aggregated over a 30-day trailing window, consecutive days are highly correlated and contain overlapping data. We cannot treat them as completely independent events without risking data leakage.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
