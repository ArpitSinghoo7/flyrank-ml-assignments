# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# I am framing this primarily as a Classification task. The goal is to classify content into categories like 'high visibility' versus 'low visibility' based on its features and search signals. This will allow us to use classification models to evaluate which specific features most strongly separate successful content from the rest.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# The target I will predict is a specific visibility or engagement metric (for example, whether a piece of content falls into the top quartile for impressions or clicks). This label comes from an observed outcome directly from the historical performance dataset, rather than a strictly defined, manual business rule.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# For this classification task, a solid success metric would be the F1-score or AUC-ROC. Because 'high-visibility' content might be a smaller percentage of the overall dataset (imbalanced classes), simple accuracy can be misleading. Achieving an F1-score above 0.70 would indicate our model is effectively capturing the underlying patterns.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

# Load the same dataset we used in Week 1
df = pd.read_csv('../../data/raw/content_refresh_anonymized.csv')

print("Unit of analysis: One row represents a single piece of content/URL and its metrics.")

# Display just one row to prove what a single unit looks like
df.head(1)

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# Search visibility is influenced by dozens of interacting variables (like word count, specific tags, and engagement rates). If we tried to use fixed rules, we would end up with an endless, unmanageable block of if/else statements that still wouldn't capture how these features blend together. Just like trying to write manual conditional rules to detect the exact curves and edges of handwritten numbers is nearly impossible, the complex relationship between content signals and visibility requires a machine learning algorithm to automatically learn the weights and decision boundaries from the data.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

# %% [markdown]
# I confirm that every section is filled, the notebook runs without errors, contains no private data, uses careful words, and is ready to be committed.
